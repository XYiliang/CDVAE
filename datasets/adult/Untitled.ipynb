# %%
import pandas as pd

# df = pd.read_csv('list_attr_adult.txt', delimiter='\t', index_col=False)
# df
for idx, line in enumerate(train_df):
    if idx != 0:
        line = line.strip('\n').split('\t')
# Out:
#              Age  Workclass  Education  Marital_Status  Occupation  \
# 0          0.jpg          1          0               1           1
# 1          1.jpg          1          0               1           0
# 2          2.jpg          1          1               0           1
# 3          3.jpg          1          1               0           0
# 4          4.jpg          0          1               1           0
# ...          ...        ...        ...             ...         ...
# 65118  65118.jpg          1          1               1           1
# 65119  65119.jpg          1          0               0           1
# 65120  65120.jpg          1          1               1           0
# 65121  65121.jpg          1          1               1           1
# 65122  65122.jpg          0          0               1           0
#
#        Relationship  Race  Sex  Hours_Per_Week  Native_Country  Income  \
# 0                 1     1    1               1               0       1
# ...
